# %% [markdown]
# -list
# -tuple
# -dictionary
# -set

# %%
print('a')
# Out:
# a

# %%
fruits = ['apple', 'banana', 'cherry']
type(fruits)
# Out:
# list

# %% [markdown]
# ###List methods
# -append()
# -clear()
# -copy()
# -count()
# -extend()
# -index()
# -insert()
# -pop()
# -remove()
# -reverse()
# -sort()

# %%
fruit=['date', 'elderberry']
fruit.append('fig')
fruit.remove('date')

# %%
fruit.count('cherry')
fruit
# Out:
# ['elderberry', 'fig', 'grape']

# %%
fruit.extend(['grape', 'honeydew'])
print(fruit)
# Out:
# ['grape', 'grape', 'grape', 'honeydew']

# %%
fruit.index('grape')
fruit.index('grape',2)
# Out:
# 2

# %%
fruit2=fruit.pop(2)
print(fruit2)
# Out:
# honeydew

# %%
fruit.remove('fig')
fruit.remove(fruit[0])

# %%
fruit.reverse()
fruit
# Out:
# ['grape', 'grape']

# %%
fruit.sort()

# %%
sorted(fruit, key=lambda x: len(x)) # sort by length of the fruit name

# %% [markdown]
# ###Tuple

# %%
a=(1,2,3,4)
type(a)
# Out:
# tuple

# %%
a[1]
slice_a = a[1:3]

# %% [markdown]
# ###Dictionary

# %%
person = {'name': 'Alice', 
          'age': 30, 
          'city': 'New York'}
type(person)
# Out:
# dict

# %%
person['age']
# Out:
# 30

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
person.values()
# Out:
# dict_values(['Alice', 30, 'New York'])

# %%
person.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York')])

# %%
dict([('name', 'Bob'), ('age', 25), ('city', 'Los Angeles')])
# Out:
# {'name': 'Bob', 'age': 25, 'city': 'Los Angeles'}

# %%
dict(name='Bob', age=25, city='Los Angeles')
# Out:
# {'name': 'Bob', 'age': 25, 'city': 'Los Angeles'}

# %%
person['lname']='Anderson'

# %%
{
    1:'mmm',
    True:'sss'
}
# Out:
# {1: 'sss'}

# %%
person.update({'sex': 'female'})
person.update({'age': 31})

# %% [markdown]
# ###Set

# %%
letter={'a','b','c'} #remove duplicates
type(letter)
# Out:
# set

# %%
s1={'a','b','c','d'}
s2={'c','d','e','f'}    
s1.union(s2)

# %%
s1 | s2
s1 & s2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s1 | s2
#       2 s1 & s2
#
# NameError: name 's1' is not defined

# %%
s1.remove('a')

# %%
s1.difference(s2)
s1-s2

# %%
s1.symmetric_difference(s2)
s1 ^ s2

# %%
'apple' in fruit

# %% [markdown]
# ###Namedtuple

# %%
from collections import namedtuple
