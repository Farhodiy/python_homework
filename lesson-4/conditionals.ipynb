# %% [markdown]
# if <condition>:
#     <statements>

# %%
authenticated=True

if authenticated:
    print('logged in')
# Out:
# logged in

# %% [markdown]
# '''
#     >
#     <
#     =
#     >=
#     <=
#     !=
# '''

# %% [markdown]
# ### Loops
